# %%
import requests

# %%
url = 'https://wise.com/us/currency-converter/usd-to-chf-rate?amount=1'

# %%
boop = requests.get(url)

# %%
text = boop.text

# %%
text.split()[0:1000]
# Out:
# ['<!DOCTYPE',
#  'html><html',
#  'lang="en-US"',
#  'dir="ltr"><head><meta',
#  'name="viewport"',
#  'content="initial-scale=1.0,',
#  'width=device-width"',
#  '/><link',
#  'rel="icon"',
#  'href="https://wise.com/public-resources/assets/icons/wise-personal/favicon.png"',
#  'type="image/x-icon"',
#  '/><link',
#  'rel="apple-touch-icon"',
#  'sizes="180x180"',
#  'href="https://wise.com/public-resources/assets/icons/wise-personal/apple_touch_icon.png"',
#  '/><link',
#  'rel="icon"',
#  'type="image/png"',
#  'sizes="32x32"',
#  'href="https://wise.com/public-resources/assets/icons/wise-personal/favicon_32x32.png"',
#  '/><link',
#  'rel="icon"',
#  'type="image/png"',
#  'sizes="16x16"',
#  'href="https://wise.com/public-resources/assets/icons/wise-personal/favicon_16x16.png"',
#  '/><link',
#  'rel="mask-icon"',
#  'href="https://wise.com/public-resources/assets/icons/wise-personal/safari_pinned_tab.svg"',
#  'color="#083400"',
#  '/><link',
#  'rel="icon"',
# ...

# %%
chf_value = float(text[text.find('1.00000 USD')+50:text.find('1.00000 USD')+57])

# %%
chf_value
# Out:
# 0.88095
